# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
# Iris veri setini yükleyin
iris = load_iris()
X = iris.data  # Özellikler (features)
y = iris.target  # Etiketler (labels)

# %%
# K-means algoritmasını 3 küme ile çalıştırıyoruz (çünkü Iris veri seti 3 tür çiçek içerir)
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

# Küme etiketlerini alalım
labels = kmeans.labels_
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Küme sonuçlarını 2D olarak görselleştirelim
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', marker='o')

# Kümelerin merkezlerini (centroids) kırmızı çarpı işaretleri ile çizelim
centroids = kmeans.cluster_centers_
centroids_pca = pca.transform(centroids)  # PCA ile 2D'ye indirgeliyoruz

plt.scatter(centroids_pca[:, 0], centroids_pca[:, 1], c='red', marker='x', s=200, label='Küme Merkezleri')

# Başlık ve etiketler
plt.title("K-means Kümeleme Sonuçları")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.colorbar(label='Küme Etiketi')

# Legend (etiketler) ekleyelim
plt.legend()

# Grafiği gösterelim
plt.show()
